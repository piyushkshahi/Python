# %% [markdown]
# <a href="https://colab.research.google.com/github/piyushkshahi/Python/blob/main/Basic_Python/Day%203/Day_3_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Earlier when discussing strings we introduced the concept of a <u>sequence</u> in Python.
# * <u>Lists</u> can be thought of the most general version of a *sequence* in Python.
#
#
# * Unlike strings, they are mutable, meaning the elements inside a list can be changed!
#
#
# * Lists are constructed with brackets <code>[]</code> and commas separating every element in the list.

# %%
a = [1,2,3,4.5,'hello']
type(a)
# Out:
# list

# %%
print(a)
# Out:
# [1, 2, 3, 4.5, 'hello']

# %% [markdown]
# ## List Indexing
# * Indexing work just like in strings.
#
#
# * A list index refers to the location of an element in a list.
#
#
# * Remember the indexing begins from 0 in Python.
#
#
# * The first element is assigned an index 0, the second element is assigned an index of 1 and so on and so forth.

# %%
print(a)
# Out:
# [1, 2, 3, 4.5, 'hello']

# %%
print(a[1])
# Out:
# 2

# %%
print(a[-1])
# Out:
# hello

# %% [markdown]
# ## List Slicing
#
# * We can use a <code>:</code> to perform *slicing* which grabs everything up to a designated point.
#
#
# * The starting index is specified on the left of the <code>:</code> and the ending index is specified on the right of the <code>:</code>.
#
#
# * Remember the element located at the right index is not included.

# %%
print(a)
# Out:
# [1, 2, 3, 4.5, 'hello']

# %%
print(a[1:])
# Out:
# [2, 3, 4.5, 'hello']

# %%
print(a[::-1])
# Out:
# ['hello', 4.5, 3, 2, 1]

# %%
print(a[-1])
# Out:
# hello

# %%
type(a[-1])
# Out:
# str

# %%
k = a[-1]

# %%
print(k[::-1])
# Out:
# olleh

# %%
print(a[-1][::-1])
# Out:
# olleh

# %% [markdown]
# ## List Operations
# * Remember we said that lists are mutable as opposed to strings. Lets see how can we change the elements of a list

# %% [markdown]
# * We can also use <code>+</code> to concatenate lists, just like we did for strings.

# %%
a = [1,2,3,4,5]
b = [4,5,6,7,8]

print(a+b)
# Out:
# [1, 2, 3, 4, 5, 4, 5, 6, 7, 8]

# %%
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(b)
# Out:
# [4, 5, 6, 7, 8]

# %% [markdown]
# ### <code>extend()</code>
#
# * Use the <code> extend()</code> method to merge a list to an existing list
#
#
# * <code> extend()</code> method takes a list or any iterable(don't worry about it now) as an argument.
#
#
# * Quite helpful when you have two or more lists and you want to merge them together

# %%
a = [1,2,3,4,5]
b = [4,5,6,7,8]

a.extend(b)

print(a)
# Out:
# [1, 2, 3, 4, 5, 4, 5, 6, 7, 8]

# %% [markdown]
# ### <code>append()</code>
#
# * Use the <code>append()</code> method to permanently add an item to the end of a list.
#
#
# * <code>append()</code> method takes the element which you want to add to the list as an argument

# %%
a = [1,2,3,4,5]

a.append('hello')
print(a)
# Out:
# [1, 2, 3, 4, 5, 'hello']

# %%
a.append('rahul')
print(a)
# Out:
# [1, 2, 3, 4, 5, 'hello', 'rahul']

# %%
a.extend('rahul')
print(a)
# Out:
# [1, 2, 3, 4, 5, 'hello', 'rahul', 'r', 'a', 'h', 'u', 'l']

# %%
a = [1,2,3,'hello']
print(a*3)
# Out:
# [1, 2, 3, 'hello', 1, 2, 3, 'hello', 1, 2, 3, 'hello']

# %%
print(a[1]*3)
# Out:
# 6

# %% [markdown]
# ## List Functions

# %% [markdown]
# ### <code>len()</code>
#
#
# * <code>len()</code> function returns the length of the list

# %%
a = [1,2,3,'hello']
print(len(a))
# Out:
# 4

# %% [markdown]
# ### <code>min()</code>
#
#
# * <code>min()</code> function returns the minimum element of the list
#
#
# * <code>min()</code> function only works with lists of similar data types

# %%
a = [1,2,3,0,100,99]

print(min(a))
# Out:
# 0

# %%
print(max(a))
# Out:
# 100

# %%
print(sum(a))
# Out:
# 205

# %%
a = [1,2,3,0,100,99,'a','b','z']

print(min(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10320/3944226043.py in <cell line: 0>()
#       1 a = [1,2,3,0,100,99,'a','b','z']
#       2
# ----> 3 print(min(a))
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
a = ['a','b','z']

print(min(a))

# %%
print(max(a))

# %%
a = ['aabhay','abhishek','aaa']

print(min(a))

# %%
print(max(a))

# %%
a = ['aabhay','abhishek','zaaaaaa']

print(min(a))

# %% [markdown]
# ### <code>sorted()</code>
#
#
# * <code>sorted()</code> function returns the sorted list
#
#
# * <code>sorted()</code> function takes reverse boolean as an argument
#
#
# * <code>sorted()</code> function only works on a list with similar data types

# %%
print(a)

# %%
print(sorted(a))

# %%
print(sorted(a,reverse = True))

# %%
a = [1,2,3,0,100,99]
print(sorted(a,reverse = True))

# %%
a = [1,2,3,0,100,99]
print(sorted(a))

# %% [markdown]
# ### <code>pop()</code>
#
# * Use <code>pop()</code> to "pop off" an item from the list.
#
#
# * By default <code>pop()</code> takes off the element at the last index, but you can also specify which index to pop off.
#
#
# * <code>pop()</code> takes the index as an argument and returns the elenent which was popped off.

# %%
a = [1,2,3,'hello']
a.pop(3)

# %%
print(a)

# %% [markdown]
# ### <code>remove()</code>
#
# * Use <code>remove()</code> to remove an item/element from the list.
#
#
# * By default <code>remove()</code> removes the specified element from the list.
#
#
# * <code>remove()</code> takes the element as an argument.

# %%
a = [1,2,3,'hello']
a.remove('hello')

# %%
print(a)

# %%
a = ['hello',1,2,3,'hello']
a.remove('hello')
print(a)

# %% [markdown]
# ### <code>count()</code>
#
#
# * The <code>count()</code> method returns the total occurrence of a specified element in the list

# %%
a = [1,2,3,1,4,5,1]
print(a.count(1))

# %% [markdown]
# ### <code>index()</code>
#
#
# * The <code>index()</code> method returns the index of a specified element.

# %%
a = [1,2,3,'hello']
print(a.index('hello'))

# %%
a = 'hello'
print(a.find('h'))

# %% [markdown]
# ### <code>reverse()</code>
#
# * <code>reverse()</code> method reverses the list

# %%
a = [1,2,3,'hello']
print(a[::-1])

# %%
print(a)

# %%
a = [1,2,3,'hello']
a.reverse()
print(a)

# %%
print(a)

# %% [markdown]
# ## Nested Lists
#
# * A great feature of of Python data structures is that they support *nesting*. This means we can have data structures within data structures. For example: A list inside a list.

# %%
a = ['rahul','mohan','sohan']
b = ['a','b','c']
c = [1,2,3]

# %%
d = [a,b,c]
print(d)
# Out:
# [['rahul', 'mohan', 'sohan'], ['a', 'b', 'c'], [1, 2, 3]]

# %%
print(len(d))
# Out:
# 3

# %%
print(d)
# Out:
# [['rahul', 'mohan', 'sohan'], ['a', 'b', 'c'], [1, 2, 3]]

# %%
print(d[0])
# Out:
# ['rahul', 'mohan', 'sohan']

# %%
print(d[0][0])
# Out:
# rahul

# %%
print(d[0][0][0])
# Out:
# r

# %%
print(d[0][0][0][0])

# %%
print(d)

# %%
print(d[0][-1][-1][-1][-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10320/3872169487.py in <cell line: 0>()
# ----> 1 print(d[0][-1][-1][-1][-1])
#
# NameError: name 'd' is not defined

# %%
print(d[1][-1][-1][-1][-1])

# %%
print(d[0])

# %%
print(d[0][1:])

# %%
a = [1,2,3,4,5,6]
a[0] = 'hello'
print(a)
