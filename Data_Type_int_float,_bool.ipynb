# %% [markdown]
# <a href="https://colab.research.google.com/github/piyushkshahi/Python/blob/main/Data_Type_int_float%2C_bool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data types in python
#
# Python is a dynamically typed language, which means you don't need to declare the data type of a variable when you create it; Python will determine the data type dynamically at runtime. However, Python has several built-in data types that you can use to store and manipulate different kinds of data. Here are some of the most common data types in Python:
#
# * ### Numeric  - Numeric variables take values which are numbers like 9, 3.14, 0, Inf
#
#
# * ### String   - 'hello',"hello"
#
#
# * ### Boolean  - True, False
#
#
# * ### Datetime  - 2023-08-05 08:21:04

# %% [markdown]
# # Integers and Floats

# %%
a = 10
type(a)
# Out:
# int

# %%
a = 1123456780
type(a)
# Out:
# int

# %%
a = 11234.56780
type(a)
# Out:
# float

# %%
a = 10.0
type(a)
# Out:
# float

# %%
a = 0.0
type(a)
# Out:
# float

# %%
a = 0
type(a)
# Out:
# int

# %%
a = 20*(1/2)
print(a)
# Out:
# 10.0

# %%
a = 0
print(a)
# Out:
# 0

# %%
a = True

type(a)
# Out:
# bool

# %%
a = False

type(a)
# Out:
# bool

# %% [markdown]
# ## Perform Arithmetic oprations

# %%
a = 10
b = 20

c = a+b
print(c)
print(a)
print(b)
# Out:
# 30
# 10
# 20

# %%
a = 10
b = 20

print(a+b)
# Out:
# 30

# %%
print(100+200)
# Out:
# 300

# %%
a = 10
b = 20

print(a-b)
# Out:
# -10

# %%
a = 10
b = 20

print(a*b)
# Out:
# 200

# %%
a = 10
b = 2

print(a/b)
# Out:
# 5.0

# %%
a = 10
b = 2

print(a//b)
# Out:
# 5

# %%
a = 10
b = 3

print(a/b)
# Out:
# 3.3333333333333335

# %%
a = 10
b = 3

print(a//b)
# Out:
# 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 10
b = 3

print(a%b)
# Out:
# 1

# %%
a = 11
b = 3

print(a%b)
# Out:
# 2

# %%
a = 12
b = 3

print(a%b)
# Out:
# 0

# %%
a = 3

print(a**2)
# Out:
# 9

# %%
a = 3
b = 6

print(a**3)
print(b**3)
# Out:
# 27
# 216

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 2

print(a**3)
# Out:
# 8

# %%
a = (10+5)*(2**2)

print(a)
# Out:
# 60

# %% [markdown]
# ## Let's Know a bout Variable?

# %%
rahul = 20

print(rahul)
# Out:
# 20

# %%
rahul = 20
Rahul = 40
print(Rahul)
# Out:
# 40

# %%
rahul singh = 20

print(rahul singh)
# Out:
#   File "/tmp/ipykernel_299/940971071.py", line 1
#     rahul singh = 20
#           ^
# SyntaxError: invalid syntax

# %%
rahul_singh = 20

print(rahul_singh)
# Out:
# 20

# %%
_rahul_singh_ = 20

print(_rahul_singh_)
# Out:
# 20

# %%
rahul1 = 20

print(rahul1)
# Out:
# 20

# %%
r2ahul1 = 20

print(r2ahul1)
# Out:
# 20

# %%
1r2ahul1 = 20

print(1r2ahul1)
# Out:
#   File "/tmp/ipykernel_299/3569747471.py", line 1
#     1r2ahul1 = 20
#     ^
# SyntaxError: invalid decimal literal

# %%
a1 = 100
print(a1)
# Out:
# 100

# %%
1a = 100
print(1a)
# Out:
#   File "/tmp/ipykernel_299/1557741713.py", line 1
#     1a = 100
#     ^
# SyntaxError: invalid decimal literal

# %%
#~ !@#$%^&*()-+=₹|}{[]\":;'?><,./"}

# %% [markdown]
# ## Comparison Operators
#
# Equal to ==
#
# Not equal to !=
#
# Greater than >
#
# Less than <
#
# Greater than or equal to >=
#
# Less than or equal to <=

# %%
a = 10
b = 20

print(a == b)
# Out:
# False

# %%
print(a != b)
# Out:
# True

# %%
print(a > b)
# Out:
# False

# %%
print(a < b)
# Out:
# True
