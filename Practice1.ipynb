# %% [markdown]
# <a href="https://colab.research.google.com/github/piyushkshahi/Python/blob/main/Practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Circcle:
  def __init__(self,r):
    self.r = r
  def area(self):
    return 3.14*r*r
  def  Su_fe(r):
    return 2*3.14*r

# %%
r = 24
d = Circcle()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2341/1688441715.py in <cell line: 0>()
#       1 r = 24
# ----> 2 d = Circcle()
#
# TypeError: Circcle.__init__() missing 1 required positional argument: 'r'
